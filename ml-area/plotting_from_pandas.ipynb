# %%
import pandas as pd
import numpy as np

# %%
df_car_sales = pd.read_csv('./data/car-sales.csv')

# %%
df_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2020", periods=1000 ))

# %%
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
df_car_sales['Price'] = df_car_sales['Price'].replace('[\$\,\.]', '',regex=True).astype(int)//100

# %%
df_car_sales['Sales Date'] = pd.date_range("1/1/2020", periods=len(df_car_sales))

# %%
df_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
df_car_sales['Total Sales'] = df_car_sales['Price'].cumsum()

# %%
df_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
df_car_sales.plot(x='Sales Date', y='Total Sales');

# %%
df_car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price', 'Sales Date',
#        'Total Sales'],
#       dtype='object')

# %%
df_car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter');

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.40608655, 0.45242053, 0.26840931, 0.87651283],
#        [0.25611886, 0.76658029, 0.91292772, 0.45009729],
#        [0.76831819, 0.95419046, 0.09409729, 0.4182456 ],
#        [0.81442652, 0.34193308, 0.6956218 , 0.67918634],
#        [0.47166022, 0.15390387, 0.72107618, 0.22304185],
#        [0.01071819, 0.27766183, 0.78704904, 0.87679667],
#        [0.32842074, 0.45240756, 0.3303495 , 0.39251676],
#        [0.05770883, 0.98837753, 0.99767376, 0.64722303],
#        [0.93661941, 0.84103055, 0.69592788, 0.6485053 ],
#        [0.91452692, 0.31431597, 0.85105257, 0.53264558]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])

# %%
50 + 200 + 50 + 100 + 300
# Out:
# 700

# %%
df.plot.bar();

# %%
df.plot(kind='bar');

# %%
df_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
df_car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');
