# %%
print('scipy')
# Out:
# scipy

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /home/raddy/.pyenv/versions/3.11.2/lib/python3.11/site-packages (1.11.3)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /home/raddy/.pyenv/versions/3.11.2/lib/python3.11/site-packages (from scipy) (1.25.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### PDF and CDF

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import norm

# %%
x = np.linspace(-6, 6, 1000)

# %%
fx = norm.pdf(x, loc=0, scale=1)

# %%
plt.plot(x, fx); # (x, y)

# %%
Fx = norm.cdf(x, loc=0, scale=1)

# %%
plt.plot(x, Fx);

# %%
logfx = norm.logpdf(x, loc=0, scale=1)

# %%
plt.plot(x, logfx);

# %% [markdown]
# ### Convolution

# %%
from PIL import Image

# %%
im = Image.open('./img/panda.png')

# %%
gray = np.mean(im, axis=2)

# %%
gray
# Out:
# array([[19.33333333, 19.33333333, 19.33333333, ..., 33.        ,
#         33.        , 33.        ],
#        [19.33333333, 19.33333333, 19.33333333, ..., 33.        ,
#         33.        , 33.        ],
#        [19.33333333, 19.33333333, 19.33333333, ..., 33.        ,
#         33.        , 33.        ],
#        ...,
#        [22.33333333, 19.33333333, 16.33333333, ...,  7.66666667,
#          7.66666667,  7.66666667],
#        [22.33333333, 19.33333333, 19.33333333, ...,  6.66666667,
#          6.66666667,  6.66666667],
#        [22.33333333, 19.33333333, 19.33333333, ...,  6.66666667,
#          6.66666667,  6.66666667]])

# %%
x = np.linspace(-6, 6, 50)

# %%
fx = norm.pdf(x, loc=0, scale=1)

# %%
filt = np.outer(fx, fx)

# %%
plt.imshow(filt, cmap='gray')

# %%
from scipy.signal import convolve2d

# %%
out =  convolve2d(gray,filt)

# %%
out =  convolve2d(gray,filt)

# %%
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.subplot(1,2,2)
plt.imshow(out, cmap='gray')
