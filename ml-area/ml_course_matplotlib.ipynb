# %% [markdown]
# ### Intorduction to Matplotlib

# %% [markdown]
# ордината - y | абсциса _ x

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4], [11, 22, 33, 44])

# %%
50177 - (600 + 700 + 400)
# Out:
# 48477
